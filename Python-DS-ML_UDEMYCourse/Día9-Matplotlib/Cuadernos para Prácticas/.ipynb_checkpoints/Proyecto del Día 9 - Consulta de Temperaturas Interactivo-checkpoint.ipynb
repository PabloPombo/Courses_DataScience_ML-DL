# %% [markdown]
# # Proyecto del Día 9: Consulta de Temperaturas Interactivo por Ciudad y Mes
#
# ## Objetivo
#
# El proyecto propuesto consistirá en la creación de un programa interactivo para la visualización de datos meteorológicos. Este programa permitirá a los usuarios visualizar los registros climáticos eligiendo el lugar y el més. El objetivo es aplicar los conceptos de creación de gráficos, personalización de estilos y combinarlo con las habilidades de desarrollo de programas con Python.
#
# ## Consigna
#
# 1. **Cargar un DataFrame** con los datos meteorológicos provistos en el archivo descargable de esta lección.
# 2. Asegúrate de que las **fechas** estén en el **formato correcto** para su manipulación posterior.
# 3. Crea un programa (una función o un conjunto de funciones) que le pida al usuario que seleccione una **ciudad** de la lista de ciudades disponibles en nuestro DataFrame, y un **mes** del año.
# 4. Muéstrale al usuario un gráfico que muestre las temperaturas mínimas y máximas que se registraron en la ciudad elegida durante el mes elegido.
# 5. El programa debe preguntarle al usuario si desea seguir haciendo consultas o no.
#
# **¡Mucha suerte!**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

df = pd.read_csv("C:/Users/Pablo/Documents/CURSOS-Aprendizaje/Courses_DataScience_ML-DL/Python-DS-ML_UDEMYCourse/Día9-Matplotlib/Datos+Meteorológicos_Arg_2023.csv") 
df
# Out:
#            Fecha        Ciudad  Temperatura Maxima  Temperatura Minima  \
# 0       1/1/2023  Buenos Aires                  27                  18
# 1       1/1/2023       Cordoba                  35                  18
# 2       1/1/2023       Rosario                  23                  21
# 3       1/1/2023       Mendoza                  35                  21
# 4       1/1/2023       Tucuman                  36                  18
# ...          ...           ...                 ...                 ...
# 1820  31/12/2023  Buenos Aires                  15                  12
# 1821  31/12/2023       Cordoba                  15                   7
# 1822  31/12/2023       Rosario                  14                   8
# 1823  31/12/2023       Mendoza                  13                   9
# 1824  31/12/2023       Tucuman                  15                  10
#
#       Precipitacion  Velocidad del Viento  Humedad Relativa
# ...

# %%
df ['Fecha'] = pd.to_datetime(df['Fecha'], format='%d/%m/%Y')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1825 entries, 0 to 1824
# Data columns (total 7 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Fecha                 1825 non-null   datetime64[ns]
#  1   Ciudad                1825 non-null   object
#  2   Temperatura Maxima    1825 non-null   int64
#  3   Temperatura Minima    1825 non-null   int64
#  4   Precipitacion         1825 non-null   float64
#  5   Velocidad del Viento  1825 non-null   float64
#  6   Humedad Relativa      1825 non-null   float64
# dtypes: datetime64[ns](1), float64(3), int64(2), object(1)
# memory usage: 99.9+ KB

# %%
def programa():
    a = 0 
    meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Nobiembre','Diciembre']
    ciudades = df['Ciudad'].unique()
    
    while True:
        
        print(ciudades)
        ciudad = input('Escribe el nombre de una Ciudad para investigar las temperaturas: ')
        mes = int(input('Escribe el numero del mes del que quieras saber: '))
        
        datos_ciudad_mes = df[(df['Ciudad'] == ciudad) & (df['Fecha'].dt.month == mes)]
    
        plt.figure(figsize=(10, 6))
        plt.plot(datos_ciudad_mes['Fecha'],datos_ciudad_mes['Temperatura Maxima'], label='Temperatura Maxima')
        plt.plot(datos_ciudad_mes['Fecha'],datos_ciudad_mes['Temperatura Minima'], label='Temperatura Minima')
        plt.title(f'Grafica de la ciudad {ciudad} del mes de {meses[int(mes)-1]}')
        plt.xlabel('Fecha')
        plt.ylabel('Temperatura')
        plt.xticks(rotation=45)
        plt.legend()
        plt.show()
        
        continuar = input('Si deseas realizar otra consulta teclea "y", sino teclea cualquier otra letra: ')
        if continuar !='y':
            break

# %%
programa()
# Out:
# ['Buenos Aires' 'Cordoba' 'Rosario' 'Mendoza' 'Tucuman']
# Escribe el nombre de una Ciudad para investigar las temperaturas: Cordoba
# Escribe el numero del mes del que quieras saber: 5
# Si deseas realizar otra consulta teclea "y", sino teclea cualquier otra letra: h

# %%
datos_ciudad_mes = df[(df['Ciudad'] == 'Buenos Aires') & (df['Fecha'].dt.month == 2)]
datos_ciudad_mes
# Out:
#          Fecha        Ciudad  Temperatura Maxima  Temperatura Minima  \
# 155 2023-02-01  Buenos Aires                  32                  21
# 160 2023-02-02  Buenos Aires                  27                  20
# 165 2023-02-03  Buenos Aires                  28                  15
# 170 2023-02-04  Buenos Aires                  23                  21
# 175 2023-02-05  Buenos Aires                  32                  17
# 180 2023-02-06  Buenos Aires                  25                  17
# 185 2023-02-07  Buenos Aires                  31                  15
# 190 2023-02-08  Buenos Aires                  31                  20
# 195 2023-02-09  Buenos Aires                  36                  17
# 200 2023-02-10  Buenos Aires                  28                  19
# 205 2023-02-11  Buenos Aires                  29                  22
# 210 2023-02-12  Buenos Aires                  26                  21
# 215 2023-02-13  Buenos Aires                  26                  17
# ...

# %%
#Prueba
ciudad = 'Buenos Aires'
mes = 3
df[(df['Ciudad'] == ciudad) & (df['Fecha'].dt.month == mes)]['Temperatura Maxima'].max()
# Out:
# 36

# %%
datos= df.groupby([df['Fecha'].dt.to_period('M'),'Ciudad'])['Temperatura Maxima'].max()
datos
# Out:
# Fecha    Ciudad
# 2023-01  Buenos Aires    35
#          Cordoba         35
#          Mendoza         36
#          Rosario         34
#          Tucuman         36
# 2023-02  Buenos Aires    36
#          Cordoba         36
#          Mendoza         36
#          Rosario         36
#          Tucuman         36
# 2023-03  Buenos Aires    36
#          Cordoba         36
#          Mendoza         36
#          Rosario         36
#          Tucuman         35
# 2023-04  Buenos Aires    24
#          Cordoba         24
#          Mendoza         24
#          Rosario         24
#          Tucuman         24
# 2023-05  Buenos Aires    24
#          Cordoba         24
#          Mendoza         24
#          Rosario         24
#          Tucuman         24
# 2023-06  Buenos Aires    16
#          Cordoba         16
#          Mendoza         16
#          Rosario         16
#          Tucuman         14
# 2023-07  Buenos Aires    16
#          Cordoba         16
# ...

# %%
# Out:
# 36

# %%
prueb = df.loc[(df['Ciudad']==ciudad) & (df['Fecha'].dt.month == mes)]
prueb1 = prueb.iloc[:, :4]
prueb2 = prueb.loc[:,['Fecha','Ciudad']]
prueb2
# Out:
#          Fecha        Ciudad
# 295 2023-03-01  Buenos Aires
# 300 2023-03-02  Buenos Aires
# 305 2023-03-03  Buenos Aires
# 310 2023-03-04  Buenos Aires
# 315 2023-03-05  Buenos Aires
# 320 2023-03-06  Buenos Aires
# 325 2023-03-07  Buenos Aires
# 330 2023-03-08  Buenos Aires
# 335 2023-03-09  Buenos Aires
# 340 2023-03-10  Buenos Aires
# 345 2023-03-11  Buenos Aires
# 350 2023-03-12  Buenos Aires
# 355 2023-03-13  Buenos Aires
# 360 2023-03-14  Buenos Aires
# 365 2023-03-15  Buenos Aires
# 370 2023-03-16  Buenos Aires
# 375 2023-03-17  Buenos Aires
# 380 2023-03-18  Buenos Aires
# 385 2023-03-19  Buenos Aires
# 390 2023-03-20  Buenos Aires
# 395 2023-03-21  Buenos Aires
# 400 2023-03-22  Buenos Aires
# 405 2023-03-23  Buenos Aires
# 410 2023-03-24  Buenos Aires
# 415 2023-03-25  Buenos Aires
# 420 2023-03-26  Buenos Aires
# 425 2023-03-27  Buenos Aires
# 430 2023-03-28  Buenos Aires
# 435 2023-03-29  Buenos Aires
# 440 2023-03-30  Buenos Aires
# 445 2023-03-31  Buenos Aires

# %%
datos_ciudad_mes = df[(df['Ciudad'] == ciudad) & (df['Fecha'].dt.month == mes)]
datos_ciudad_mes
# Out:
#          Fecha        Ciudad  Temperatura Maxima  Temperatura Minima  \
# 295 2023-03-01  Buenos Aires                  35                  21
# 300 2023-03-02  Buenos Aires                  28                  21
# 305 2023-03-03  Buenos Aires                  25                  22
# 310 2023-03-04  Buenos Aires                  31                  22
# 315 2023-03-05  Buenos Aires                  36                  16
# 320 2023-03-06  Buenos Aires                  22                  21
# 325 2023-03-07  Buenos Aires                  29                  20
# 330 2023-03-08  Buenos Aires                  36                  21
# 335 2023-03-09  Buenos Aires                  33                  19
# 340 2023-03-10  Buenos Aires                  31                  21
# 345 2023-03-11  Buenos Aires                  22                  18
# 350 2023-03-12  Buenos Aires                  33                  18
# 355 2023-03-13  Buenos Aires                  34                  19
# ...

# %%
df[(df['Ciudad'] == 'Buenos Aires') & (df['Fecha'].dt.month == 2)]['Temperatura Maxima'].max()
# Out:
# 36

# %%
maxima = df[(df['Ciudad'] == ciudad) & (df['Fecha'].dt.month == mes)]['Temperatura Maxima'].max()
minima = df[(df['Ciudad'] == ciudad) & (df['Fecha'].dt.month == mes)]['Temperatura Minima'].min()
    
x = ['Temperatura Maxima', 'Temperatura Minima']
y = [maxima, minima]
    
plt.bar(x,y)
# Out:
# <BarContainer object of 2 artists>

# %%
 meses = ['Enero', 'Febrero', 'Marzo', 'Abril', 'Mayo', 'Junio', 'Julio', 'Agosto', 'Septiembre', 'Octubre', 'Nobiembre','Diciembre']
print(f'Grafica de la ciudad del mes {meses[1]}')
# Out:
# Grafica de la ciudad del mes Febrero

# %%
a = np.arange(20,100)

# %%
serie = pd.Series(a,name='Numeros')
serie
# Out:
# 0     20
# 1     21
# 2     22
# 3     23
# 4     24
#       ..
# 75    95
# 76    96
# 77    97
# 78    98
# 79    99
# Name: Numeros, Length: 80, dtype: int32

# %%
serie2 = serie.astype(str)+' 102'
serie2
# Out:
# 0     20 102
# 1     21 102
# 2     22 102
# 3     23 102
# 4     24 102
#        ...
# 75    95 102
# 76    96 102
# 77    97 102
# 78    98 102
# 79    99 102
# Name: Numeros, Length: 80, dtype: object

# %%
serie3 = serie2.str.split().str[0]
serie3
# Out:
# 0     20
# 1     21
# 2     22
# 3     23
# 4     24
#       ..
# 75    95
# 76    96
# 77    97
# 78    98
# 79    99
# Name: Numeros, Length: 80, dtype: object
